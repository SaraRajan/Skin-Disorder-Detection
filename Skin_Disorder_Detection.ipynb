# %% [markdown]
# ## Skin Disease Disorder

# %% [raw]
#  The medical sector considers the detection and observation of skin diseases to be a major concern. The number of individuals encountering skin-related problems is growing more quickly due to increasing pollution and consumption of subpar food. The major concern isn't health, but having bad skin makes us less confident. Regularly inspecting your skin is an important step in identifying any degenerative or early changes in your skin that could lead to skin disease. Machine learning techniques can aid in the development of strong frameworks that can classify many types of skin diseases.

# %%
#importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the data
data=pd.read_csv('Skin Disorder.csv')

# %%
data
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %% [markdown]
# ## Basic Checks

# %%
data.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                           1                  0  ...
# ...

# %%
data.tail()
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 361                  0                   0                         0
# 362                  0                   0                         0
# 363                  2                   0                         2
# 364                  3                   0                         2
# 365                  0                   0                         0
#
#      knee_and_elbow_involvement  scalp_involvement  ...  \
# 361                           0                  0  ...
# ...

# %% [markdown]
# > ### Class Distribution
#
# - '1' is representing Psoriasis disease
# - '2' is representing Seboreic Dermatitis disease
# - '3' is representing Lichen Planus disease
# - '4' is representing Pityriasis Rosea disease
# - '5' is representing Cronic Dermatitis disease
# - '6' is representing Pityriasis Rubra Pilaris disease

# %%
# Statistical Analysis
data.describe()
# Out:
#          erythema     scaling  definite_borders     itching  \
# count  366.000000  366.000000        366.000000  366.000000
# mean     2.068306    1.795082          1.549180    1.366120
# std      0.664753    0.701527          0.907525    1.138299
# min      0.000000    0.000000          0.000000    0.000000
# 25%      2.000000    1.000000          1.000000    0.000000
# 50%      2.000000    2.000000          2.000000    1.000000
# 75%      2.000000    2.000000          2.000000    2.000000
# max      3.000000    3.000000          3.000000    3.000000
#
#        koebner_phenomenon  polygonal_papules  follicular_papules  \
# count          366.000000         366.000000          366.000000
# mean             0.633880           0.448087            0.166667
# std              0.908016           0.957327            0.570588
# min              0.000000           0.000000            0.000000
# 25%              0.000000           0.000000            0.000000
# ...

# %% [markdown]
# - 366 observations are present in this dataset.
# - Almost every feature contains 4 unique values 0,1,2,3.
#
#  - 0 indicates that the feature was not present.
#  - 3 indicates the largest amount possible.
#  - 1, 2 indicate the relative intermediate values.

# %%
data.shape
# Out:
# (366, 35)

# %% [markdown]
# - This dataset includes 366 samples/observations and 35 columns.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   erythema                                  366 non-null    int64
#  1   scaling                                   366 non-null    int64
#  2   definite_borders                          366 non-null    int64
#  3   itching                                   366 non-null    int64
#  4   koebner_phenomenon                        366 non-null    int64
#  5   polygonal_papules                         366 non-null    int64
#  6   follicular_papules                        366 non-null    int64
#  7   oral_mucosal_involvement                  366 non-null    int64
#  8   knee_and_elbow_involvement                366 non-null    int64
#  9   scalp_involvement                         366 non-null    int64
# ...

# %% [markdown]
# - The data type of "Age" is in object type & rest all other features are of integer type

# %%
data.columns
# Out:
# Index(['erythema', 'scaling', 'definite_borders', 'itching',
#        'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
#        'oral_mucosal_involvement', 'knee_and_elbow_involvement',
#        'scalp_involvement', 'family_history', 'melanin_incontinence',
#        'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
#        'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
#        'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
#        'elongation_of_the_rete_ridges',
#        'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
#        'munro_microabcess', 'focal_hypergranulosis',
#        'disappearance_of_the_granular_layer',
#        'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
#        'saw-tooth_appearance_of_retes', 'follicular_horn_plug',
#        'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
#        'band-like_infiltrate', 'Age', 'class'],
#       dtype='object')

# %%
data['class'].value_counts()
# Out:
# 1    112
# 3     72
# 2     61
# 5     52
# 4     49
# 6     20
# Name: class, dtype: int64

# %% [markdown]
# ## EDA

# %%
data.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                           1                  0  ...
# ...

# %%
plt.figure(figsize=(6,6), facecolor='white')
sns.countplot(x=data["class"])
plt.show()

# %% [markdown]
# - According to dataset it can be seen that there are highest number of people who are suffering from " psoriasis " skin disorder.

# %%
data.loc[data['Age']=="?","Age"]=0

# %%
data[["Age"]]=data[["Age"]].astype("int64")

# %%
plt.figure(figsize=(6,5), facecolor='white')
sns.barplot(x= data["class"],y= data["Age"])
plt.show()

# %% [markdown]
# The main thing we can conclude from this comparision that "pityriasis_rubra_pilaris" skin disorder effects almost 0 - 10 years age group people.
# It means this skin disorder only affects children.
# Where as rest 5 skin disorders can take place at any age.

# %%
# SKIN DISORDER PRESENT IN THE FAMILY EFFECTS
plt.figure(figsize=(8,5),facecolor="white")
sns.barplot(x=data["class"],y=data["family_history"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The main thing we can conclude from this comparision that "pityriasis_rubra_pilaris" skin disorder effects almost 0 - 10 years age group people.
# It means this skin disorder only affects children.
# Where as rest 5 skin disorders can take place at any age.

# %%
data1=data[["erythema"]]
plt.figure(figsize=(30,10), facecolor='white')
plotnumber=1
for i in data1:
    if plotnumber<=10:
        plt.subplot(2,5,plotnumber)
        sns.barplot(y=data1[i],x=data["class"])
        plt.xlabel("class")
        plt.xticks(rotation=90)
    plotnumber+=1  

plt.show()

# %%
## Using Sweetwiz to visualize the large data set
# !pip install sweetviz
import sweetviz as sv #importing sweetviz library 
my_report = sv.analyze(data)#syntax to use sweetviz
my_report.show_html()
# Out:
# ...
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
sns.countplot(x='erythema',data=data)
# Out:
# <AxesSubplot:xlabel='erythema', ylabel='count'>

# %%
data.erythema.value_counts()
# Out:
# 2    215
# 3     90
# 1     57
# 0      4
# Name: erythema, dtype: int64

# %%
sns.histplot(x='erythema',hue='class',data=data,kde=True)
# Out:
# <AxesSubplot:xlabel='erythema', ylabel='Count'>

# %%
plt.figure(figsize=(25,30),facecolor='white')
plotnumber=1

for column in data:
    if plotnumber<=35:
        ax=plt.subplot(6,6,plotnumber)
        sns.histplot(data[column],kde=True)
        plt.xlabel(column,fontsize=15)
        plt.ylabel('count',fontsize=15)
        plotnumber+=1
plt.tight_layout()

# %%
for column in data:
    print(column)
# Out:
# erythema
# scaling
# definite_borders
# itching
# koebner_phenomenon
# polygonal_papules
# follicular_papules
# oral_mucosal_involvement
# knee_and_elbow_involvement
# scalp_involvement
# family_history
# melanin_incontinence
# eosinophils_in_the_infiltrate
# PNL_infiltrate
# fibrosis_of_the_papillary_dermis
# exocytosis
# acanthosis
# hyperkeratosis
# parakeratosis
# clubbing_of_the_rete_ridges
# elongation_of_the_rete_ridges
# thinning_of_the_suprapapillary_epidermis
# spongiform_pustule
# munro_microabcess
# focal_hypergranulosis
# disappearance_of_the_granular_layer
# vacuolisation_and_damage_of_basal_layer
# spongiosis
# saw-tooth_appearance_of_retes
# follicular_horn_plug
# perifollicular_parakeratosis
# inflammatory_monoluclear_inflitrate
# band-like_infiltrate
# Age
# class

# %%
sns.countplot(x='erythema',hue='class',data=data)
plt.show()

# %% [markdown]
# 1) from given data erythema range 2 are mostly occupied in class 1
# 2) erythema range 1 mostly occupied in class 5

# %%
sns.countplot(x='scaling',hue='class',data=data)
# Out:
# <AxesSubplot:xlabel='scaling', ylabel='count'>

# %% [markdown]
# 1) from given data scaling range 2,3 is mostly occupied n class 1

# %%
plt.figure(figsize=(30,30))
plotno=1
for feature in dis:
    if plotno<=36:
        ax=plt.subplot(6,6,plotno)
        sns.countplot(x=feature,data=data,hue="class")
        plt.xlabel(feature)
        plt.ylabel("Count")
    plotno+=1
plt.tight_layout()

# %%
data1=data[['erythema', 'scaling', 'definite_borders', 'itching',
       'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
       'oral_mucosal_involvement', 'knee_and_elbow_involvement',
       'scalp_involvement', 'family_history', 'melanin_incontinence',
       'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
       'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
       'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
       'elongation_of_the_rete_ridges',
       'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
       'munro_microabcess', 'focal_hypergranulosis',
       'disappearance_of_the_granular_layer',
       'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
       'saw-tooth_appearance_of_retes', 'follicular_horn_plug',
       'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
       'band-like_infiltrate', 'Age']]
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for i in data1:
    if plotnumber<=35:
        plt.subplot(6,6,plotnumber)
        sns.barplot(y=data1[i],x=data['class'])
        plt.xlabel('class')
    plotnumber +=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ### DATA PREPROCESSING

# %%
data.isnull().sum()
# Out:
# erythema                                    0
# scaling                                     0
# definite_borders                            0
# itching                                     0
# koebner_phenomenon                          0
# polygonal_papules                           0
# follicular_papules                          0
# oral_mucosal_involvement                    0
# knee_and_elbow_involvement                  0
# scalp_involvement                           0
# family_history                              0
# melanin_incontinence                        0
# eosinophils_in_the_infiltrate               0
# PNL_infiltrate                              0
# fibrosis_of_the_papillary_dermis            0
# exocytosis                                  0
# acanthosis                                  0
# hyperkeratosis                              0
# parakeratosis                               0
# clubbing_of_the_rete_ridges                 0
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize=(20,25),facecolor="white")
plotnumber=1
for column in data.columns[:-1]:
    plt.subplot(6,6,plotnumber)
    sns.boxplot(x =column,data=data)
    plotnumber +=1
plt.tight_layout()

# %%
import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize=(15,20))
plotnumber=1
for column in data.columns[:-1]:
    plt.subplot(6,6,plotnumber)
    sns.distplot(data[column])
    plotnumber +=1
plt.tight_layout()

# %%
data.corr()
# Out:
#                                           erythema   scaling  \
# erythema                                  1.000000  0.435467
# scaling                                   0.435467  1.000000
# definite_borders                          0.260087  0.357987
# itching                                  -0.047623 -0.084197
# koebner_phenomenon                        0.000694 -0.010576
# polygonal_papules                         0.033571 -0.075035
# follicular_papules                       -0.109550 -0.092400
# oral_mucosal_involvement                 -0.026810 -0.082969
# knee_and_elbow_involvement                0.141008  0.298398
# scalp_involvement                         0.186684  0.301577
# family_history                            0.172059  0.181491
# melanin_incontinence                      0.042126 -0.074856
# eosinophils_in_the_infiltrate             0.075228  0.042211
# PNL_infiltrate                            0.224095  0.282486
# ...

# %%
#checking correlation
plt.figure(figsize=(30,25))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### MODEL CREATION

# %%
X=data.drop('class',axis=1)
Y=data['class']

# %%
Y
# Out:
# 0      2
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 361    4
# 362    4
# 363    3
# 364    3
# 365    1
# Name: class, Length: 366, dtype: int64

# %%
X
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=45,test_size=0.25)

# %%
Y_test
# Out:
# 157    3
# 284    2
# 172    1
# 149    2
# 194    1
#       ..
# 356    1
# 180    1
# 30     1
# 279    4
# 22     5
# Name: class, Length: 92, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)

# %%
print(X_train_scaled)
# Out:
# [[-0.06931288  1.7737226   0.50700638 ...  0.16554513 -0.52037255
#   -0.53618859]
#  [-1.53021515  0.34431086  0.50700638 ... -1.20898108 -0.52037255
#    1.1778276 ]
#  [ 1.39158939  0.34431086  0.50700638 ... -1.20898108 -0.52037255
#    1.1778276 ]
#  ...
#  [-0.06931288 -1.08510089 -1.64678817 ... -1.20898108 -0.52037255
#   -1.08712236]
#  [-0.06931288  1.7737226   1.58390366 ... -1.20898108 -0.52037255
#   -0.10768454]
#  [-0.06931288  0.34431086  0.50700638 ...  1.54007133 -0.52037255
#    0.25960464]]

# %%
X_test_scaled= scaler.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[ 1.39158939,  1.7737226 ,  0.50700638, ...,  0.16554513,
#          2.16985534, -0.23011427],
#        [-0.06931288,  0.34431086,  0.50700638, ...,  0.16554513,
#         -0.52037255,  2.09605055],
#        [ 1.39158939,  0.34431086,  1.58390366, ..., -1.20898108,
#         -0.52037255,  1.23904246],
#        ...,
#        [ 1.39158939,  0.34431086, -0.56989089, ..., -1.20898108,
#         -0.52037255,  0.87175328],
#        [-0.06931288,  0.34431086, -0.56989089, ...,  0.16554513,
#         -0.52037255,  0.87175328],
#        [-0.06931288,  0.34431086, -1.64678817, ...,  0.16554513,
#         -0.52037255,  0.38203437]])

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression()
lr.fit(X_train_scaled,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred=lr.predict(X_test_scaled)

# %%
Y_test
# Out:
# 157    3
# 284    2
# 172    1
# 149    2
# 194    1
#       ..
# 356    1
# 180    1
# 30     1
# 279    4
# 22     5
# Name: class, Length: 92, dtype: int64

# %%
Y_pred
# Out:
# array([3, 2, 1, 2, 1, 3, 1, 1, 5, 5, 2, 6, 2, 6, 3, 1, 4, 1, 5, 6, 3, 2,
#        1, 1, 5, 1, 3, 6, 2, 4, 4, 3, 1, 4, 2, 1, 1, 1, 5, 4, 1, 1, 1, 2,
#        1, 4, 3, 1, 4, 3, 2, 2, 3, 1, 3, 3, 3, 4, 3, 5, 1, 2, 4, 5, 1, 5,
#        4, 3, 1, 2, 1, 1, 4, 6, 1, 2, 4, 4, 4, 5, 1, 1, 1, 6, 4, 2, 3, 1,
#        1, 1, 4, 5], dtype=int64)

# %%
lr.predict_proba(X_test_scaled)
# Out:
# array([[7.20512068e-05, 7.43704483e-03, 9.92340462e-01, 4.54307267e-05,
#         2.97314365e-05, 7.52797094e-05],
#        [9.15972885e-03, 5.35553434e-01, 8.63880337e-03, 4.16426418e-01,
#         2.77200570e-02, 2.50155848e-03],
#        [9.99557078e-01, 1.87333840e-04, 2.79046470e-05, 1.24932980e-04,
#         6.73467475e-05, 3.54034463e-05],
#        [1.09666927e-03, 9.46884442e-01, 1.31819657e-03, 4.46746730e-02,
#         4.78273200e-03, 1.24328734e-03],
#        [9.99997500e-01, 2.16191536e-07, 2.49950017e-07, 5.73362698e-08,
#         1.97932446e-07, 1.77889791e-06],
#        [3.03067086e-04, 7.39965244e-05, 9.97434281e-01, 2.05623121e-03,
#         6.98207481e-05, 6.26035567e-05],
#        [9.99537381e-01, 3.83257002e-06, 4.54898370e-05, 1.71017633e-04,
#         1.74685645e-04, 6.75932837e-05],
#        [9.94355101e-01, 2.70907711e-04, 3.32677170e-04, 3.03038784e-03,
#         1.30412536e-03, 7.06801090e-04],
# ...

# %%
from sklearn.metrics import classification_report,accuracy_score,recall_score,precision_score,roc_auc_score

# %%
print(accuracy_score(Y_test,Y_pred))
# Out:
# 0.9891304347826086

# %%
print(precision_score(Y_test,Y_pred,average='weighted'))
# Out:
# 0.9898097826086957

# %%
print(recall_score(Y_test,Y_pred,average='weighted'))
# Out:
# 0.9891304347826086

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        31
#            2       1.00      0.93      0.97        15
#            3       1.00      1.00      1.00        15
#            4       0.94      1.00      0.97        15
#            5       1.00      1.00      1.00        10
#            6       1.00      1.00      1.00         6
#
#     accuracy                           0.99        92
#    macro avg       0.99      0.99      0.99        92
# weighted avg       0.99      0.99      0.99        92
